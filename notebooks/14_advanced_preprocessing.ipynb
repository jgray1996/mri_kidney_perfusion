# %%
import SimpleITK as sitk
import os

def preprocess_mri_pipeline(input_dir: str, output_dir: str, reference_image_path: str):
    """
    Applies N4 bias field correction and histogram matching to a directory of MRI scans.

    Args:
        input_dir (str): The directory containing the MRI scans to be processed.
        output_dir (str): The directory where the processed scans will be saved.
        reference_image_path (str): The path to the reference MRI scan for histogram matching.
    """

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # --- 1. Load the Reference Image ---
    print(f"Loading reference image from: {reference_image_path}")
    reference_image = sitk.ReadImage(reference_image_path, sitk.sitkFloat32)

    # --- 2. Iterate Through the Dataset ---
    for filename in os.listdir(input_dir):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)

        # Process only files, and you might want to add a check for .nrrd
        if os.path.isfile(input_path) and filename.endswith(".nrrd"):
            print(f"\nProcessing: {filename}")

            # --- 3. Load the Input Image ---
            input_image = sitk.ReadImage(input_path, sitk.sitkFloat32)

            # --- 4. N4 Bias Field Correction ---
            print("Applying N4 bias field correction...")
            mask_image = sitk.OtsuThreshold(input_image, 0, 1, 200)
            corrector = sitk.N4BiasFieldCorrectionImageFilter()
            corrected_image = corrector.Execute(input_image, mask_image)

            # --- 5. Histogram Matching (Corrected) ---
            print("Applying histogram matching...")
            matcher = sitk.HistogramMatchingImageFilter()
            matcher.SetNumberOfHistogramLevels(1024)
            matcher.SetNumberOfMatchPoints(7)
            matcher.ThresholdAtMeanIntensityOn()
            
            # The reference_image is now passed directly to Execute
            matched_image = matcher.Execute(corrected_image, reference_image)

            print("Rescaling intensities to [0, 1]...")
            rescaler = sitk.RescaleIntensityImageFilter()
            rescaler.SetOutputMinimum(0.0)
            rescaler.SetOutputMaximum(1.0)
            scaled_image = rescaler.Execute(matched_image)

            # --- 6. Save the Processed Image ---
            print(f"Saving processed image to: {output_path}")
            sitk.WriteImage(scaled_image, output_path)

    print("\n--- Preprocessing complete for all images. ---")

# %%
preprocess_mri_pipeline("../nnUNet_raw/Dataset001_T1/imagesTr/", 
                        "../nnUNet_raw/Dataset001_T1/imagesPr/",
                        "../nnUNet_raw/Dataset001_T1/imagesTr/T1_000_0000.nrrd")
# Out:
# Loading reference image from: ../nnUNet_raw/Dataset001_T1/imagesTr/T1_000_0000.nrrd
#
# Processing: T1_012_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_012_0000.nrrd
#
# Processing: T1_006_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_006_0000.nrrd
#
# Processing: T1_027_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_027_0000.nrrd
#
# Processing: T1_033_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_033_0000.nrrd
#
# Processing: T1_019_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_019_0000.nrrd
#
# Processing: T1_021_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_021_0000.nrrd
#
# Processing: T1_035_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_035_0000.nrrd
#
# Processing: T1_014_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_014_0000.nrrd
#
# Processing: T1_000_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_000_0000.nrrd
#
# Processing: T1_007_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_007_0000.nrrd
#
# Processing: T1_013_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_013_0000.nrrd
#
# Processing: T1_032_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_032_0000.nrrd
#
# Processing: T1_026_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_026_0000.nrrd
#
# Processing: T1_018_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_018_0000.nrrd
#
# Processing: T1_034_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_034_0000.nrrd
#
# Processing: T1_020_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_020_0000.nrrd
#
# Processing: T1_001_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_001_0000.nrrd
#
# Processing: T1_015_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_015_0000.nrrd
#
# Processing: T1_028_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_028_0000.nrrd
#
# Processing: T1_009_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_009_0000.nrrd
#
# Processing: T1_025_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_025_0000.nrrd
#
# Processing: T1_031_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_031_0000.nrrd
#
# Processing: T1_010_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_010_0000.nrrd
#
# Processing: T1_004_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_004_0000.nrrd
#
# Processing: T1_016_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_016_0000.nrrd
#
# Processing: T1_002_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_002_0000.nrrd
#
# Processing: T1_023_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_023_0000.nrrd
#
# Processing: T1_037_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_037_0000.nrrd
#
# Processing: T1_029_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_029_0000.nrrd
#
# Processing: T1_008_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_008_0000.nrrd
#
# Processing: T1_030_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_030_0000.nrrd
#
# Processing: T1_024_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_024_0000.nrrd
#
# Processing: T1_005_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_005_0000.nrrd
#
# Processing: T1_011_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_011_0000.nrrd
#
# Processing: T1_003_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_003_0000.nrrd
#
# Processing: T1_017_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_017_0000.nrrd
#
# Processing: T1_036_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_036_0000.nrrd
#
# Processing: T1_022_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset001_T1/imagesPr/T1_022_0000.nrrd
#
# --- Preprocessing complete for all images. ---

# %%
preprocess_mri_pipeline("../nnUNet_raw/Dataset002_T2/imagesTr/", 
                        "../nnUNet_raw/Dataset002_T2/imagesPr/",
                        "../nnUNet_raw/Dataset002_T2/imagesTr/T2_000_0000.nrrd")
# Out:
# Loading reference image from: ../nnUNet_raw/Dataset002_T2/imagesTr/T2_000_0000.nrrd
#
# Processing: T2_021_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_021_0000.nrrd
#
# Processing: T2_035_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_035_0000.nrrd
#
# Processing: T2_014_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_014_0000.nrrd
#
# Processing: T2_000_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_000_0000.nrrd
#
# Processing: T2_056_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_056_0000.nrrd
#
# Processing: T2_042_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_042_0000.nrrd
#
# Processing: T2_038_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_038_0000.nrrd
#
# Processing: T2_063_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_063_0000.nrrd
#
# Processing: T2_019_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_019_0000.nrrd
#
# Processing: T2_077_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_077_0000.nrrd
#
# Processing: T2_012_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_012_0000.nrrd
#
# Processing: T2_068_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_068_0000.nrrd
#
# Processing: T2_006_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_006_0000.nrrd
#
# Processing: T2_027_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_027_0000.nrrd
#
# Processing: T2_033_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_033_0000.nrrd
#
# Processing: T2_049_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_049_0000.nrrd
#
# Processing: T2_080_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_080_0000.nrrd
#
# Processing: T2_065_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_065_0000.nrrd
#
# Processing: T2_071_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_071_0000.nrrd
#
# Processing: T2_050_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_050_0000.nrrd
#
# Processing: T2_044_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_044_0000.nrrd
#
# Processing: T2_034_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_034_0000.nrrd
#
# Processing: T2_020_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_020_0000.nrrd
#
# Processing: T2_001_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_001_0000.nrrd
#
# Processing: T2_015_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_015_0000.nrrd
#
# Processing: T2_043_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_043_0000.nrrd
#
# Processing: T2_039_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_039_0000.nrrd
#
# Processing: T2_057_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_057_0000.nrrd
#
# Processing: T2_076_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_076_0000.nrrd
#
# Processing: T2_062_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_062_0000.nrrd
#
# Processing: T2_018_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_018_0000.nrrd
#
# Processing: T2_007_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_007_0000.nrrd
#
# Processing: T2_013_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_013_0000.nrrd
#
# Processing: T2_069_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_069_0000.nrrd
#
# Processing: T2_032_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_032_0000.nrrd
#
# Processing: T2_048_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_048_0000.nrrd
#
# Processing: T2_081_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_081_0000.nrrd
#
# Processing: T2_026_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_026_0000.nrrd
#
# Processing: T2_070_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_070_0000.nrrd
#
# Processing: T2_064_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_064_0000.nrrd
#
# Processing: T2_045_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_045_0000.nrrd
#
# Processing: T2_051_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_051_0000.nrrd
#
# Processing: T2_016_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_016_0000.nrrd
#
# Processing: T2_002_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_002_0000.nrrd
#
# Processing: T2_078_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_078_0000.nrrd
#
# Processing: T2_023_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_023_0000.nrrd
#
# Processing: T2_059_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_059_0000.nrrd
#
# Processing: T2_037_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_037_0000.nrrd
#
# Processing: T2_061_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_061_0000.nrrd
#
# Processing: T2_075_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_075_0000.nrrd
#
# Processing: T2_054_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_054_0000.nrrd
#
# Processing: T2_040_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_040_0000.nrrd
#
# Processing: T2_025_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_025_0000.nrrd
#
# Processing: T2_031_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_031_0000.nrrd
#
# Processing: T2_010_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_010_0000.nrrd
#
# Processing: T2_004_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_004_0000.nrrd
#
# Processing: T2_052_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_052_0000.nrrd
#
# Processing: T2_028_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_028_0000.nrrd
#
# Processing: T2_046_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_046_0000.nrrd
#
# Processing: T2_067_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_067_0000.nrrd
#
# Processing: T2_073_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_073_0000.nrrd
#
# Processing: T2_009_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_009_0000.nrrd
#
# Processing: T2_003_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_003_0000.nrrd
#
# Processing: T2_079_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_079_0000.nrrd
#
# Processing: T2_017_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_017_0000.nrrd
#
# Processing: T2_036_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_036_0000.nrrd
#
# Processing: T2_022_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_022_0000.nrrd
#
# Processing: T2_058_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_058_0000.nrrd
#
# Processing: T2_074_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_074_0000.nrrd
#
# Processing: T2_060_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_060_0000.nrrd
#
# Processing: T2_041_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_041_0000.nrrd
#
# Processing: T2_055_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_055_0000.nrrd
#
# Processing: T2_030_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_030_0000.nrrd
#
# Processing: T2_024_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_024_0000.nrrd
#
# Processing: T2_005_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_005_0000.nrrd
#
# Processing: T2_011_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_011_0000.nrrd
#
# Processing: T2_047_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_047_0000.nrrd
#
# Processing: T2_053_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_053_0000.nrrd
#
# Processing: T2_029_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_029_0000.nrrd
#
# Processing: T2_072_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_072_0000.nrrd
#
# Processing: T2_008_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_008_0000.nrrd
#
# Processing: T2_066_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset002_T2/imagesPr/T2_066_0000.nrrd
#
# --- Preprocessing complete for all images. ---

# %%
preprocess_mri_pipeline("../nnUNet_raw/Dataset003_T2star/imagesTr/", 
                        "../nnUNet_raw/Dataset003_T2star/imagesPr/",
                        "../nnUNet_raw/Dataset003_T2star/imagesTr/T2star_000_0000.nrrd")
# Out:
# Loading reference image from: ../nnUNet_raw/Dataset003_T2star/imagesTr/T2star_000_0000.nrrd
#
# Processing: T2star_069_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_069_0000.nrrd
#
# Processing: T2star_013_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_013_0000.nrrd
#
# Processing: T2star_007_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_007_0000.nrrd
#
# Processing: T2star_026_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_026_0000.nrrd
#
# Processing: T2star_081_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_081_0000.nrrd
#
# Processing: T2star_048_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_048_0000.nrrd
#
# Processing: T2star_032_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_032_0000.nrrd
#
# Processing: T2star_064_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_064_0000.nrrd
#
# Processing: T2star_070_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_070_0000.nrrd
#
# Processing: T2star_051_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_051_0000.nrrd
#
# Processing: T2star_045_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_045_0000.nrrd
#
# Processing: T2star_020_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_020_0000.nrrd
#
# Processing: T2star_034_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_034_0000.nrrd
#
# Processing: T2star_015_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_015_0000.nrrd
#
# Processing: T2star_001_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_001_0000.nrrd
#
# Processing: T2star_057_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_057_0000.nrrd
#
# Processing: T2star_039_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_039_0000.nrrd
#
# Processing: T2star_043_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_043_0000.nrrd
#
# Processing: T2star_018_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_018_0000.nrrd
#
# Processing: T2star_062_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_062_0000.nrrd
#
# Processing: T2star_076_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_076_0000.nrrd
#
# Processing: T2star_006_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_006_0000.nrrd
#
# Processing: T2star_068_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_068_0000.nrrd
#
# Processing: T2star_012_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_012_0000.nrrd
#
# Processing: T2star_080_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_080_0000.nrrd
#
# Processing: T2star_049_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_049_0000.nrrd
#
# Processing: T2star_033_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_033_0000.nrrd
#
# Processing: T2star_027_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_027_0000.nrrd
#
# Processing: T2star_071_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_071_0000.nrrd
#
# Processing: T2star_065_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_065_0000.nrrd
#
# Processing: T2star_044_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_044_0000.nrrd
#
# Processing: T2star_050_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_050_0000.nrrd
#
# Processing: T2star_035_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_035_0000.nrrd
#
# Processing: T2star_021_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_021_0000.nrrd
#
# Processing: T2star_000_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_000_0000.nrrd
#
# Processing: T2star_014_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_014_0000.nrrd
#
# Processing: T2star_038_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_038_0000.nrrd
#
# Processing: T2star_042_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_042_0000.nrrd
#
# Processing: T2star_056_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_056_0000.nrrd
#
# Processing: T2star_077_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_077_0000.nrrd
#
# Processing: T2star_019_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_019_0000.nrrd
#
# Processing: T2star_063_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_063_0000.nrrd
#
# Processing: T2star_024_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_024_0000.nrrd
#
# Processing: T2star_083_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_083_0000.nrrd
#
# Processing: T2star_030_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_030_0000.nrrd
#
# Processing: T2star_011_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_011_0000.nrrd
#
# Processing: T2star_005_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_005_0000.nrrd
#
# Processing: T2star_029_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_029_0000.nrrd
#
# Processing: T2star_053_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_053_0000.nrrd
#
# Processing: T2star_047_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_047_0000.nrrd
#
# Processing: T2star_066_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_066_0000.nrrd
#
# Processing: T2star_008_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_008_0000.nrrd
#
# Processing: T2star_072_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_072_0000.nrrd
#
# Processing: T2star_017_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_017_0000.nrrd
#
# Processing: T2star_079_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_079_0000.nrrd
#
# Processing: T2star_003_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_003_0000.nrrd
#
# Processing: T2star_058_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_058_0000.nrrd
#
# Processing: T2star_022_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_022_0000.nrrd
#
# Processing: T2star_036_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_036_0000.nrrd
#
# Processing: T2star_060_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_060_0000.nrrd
#
# Processing: T2star_074_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_074_0000.nrrd
#
# Processing: T2star_055_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_055_0000.nrrd
#
# Processing: T2star_041_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_041_0000.nrrd
#
# Processing: T2star_082_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_082_0000.nrrd
#
# Processing: T2star_031_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_031_0000.nrrd
#
# Processing: T2star_025_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_025_0000.nrrd
#
# Processing: T2star_004_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_004_0000.nrrd
#
# Processing: T2star_010_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_010_0000.nrrd
#
# Processing: T2star_046_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_046_0000.nrrd
#
# Processing: T2star_028_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_028_0000.nrrd
#
# Processing: T2star_052_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_052_0000.nrrd
#
# Processing: T2star_009_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_009_0000.nrrd
#
# Processing: T2star_073_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_073_0000.nrrd
#
# Processing: T2star_067_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_067_0000.nrrd
#
# Processing: T2star_078_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_078_0000.nrrd
#
# Processing: T2star_002_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_002_0000.nrrd
#
# Processing: T2star_016_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_016_0000.nrrd
#
# Processing: T2star_037_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_037_0000.nrrd
#
# Processing: T2star_084_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_084_0000.nrrd
#
# Processing: T2star_059_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_059_0000.nrrd
#
# Processing: T2star_023_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_023_0000.nrrd
#
# Processing: T2star_075_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_075_0000.nrrd
#
# Processing: T2star_061_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_061_0000.nrrd
#
# Processing: T2star_040_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_040_0000.nrrd
#
# Processing: T2star_054_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset003_T2star/imagesPr/T2star_054_0000.nrrd
#
# --- Preprocessing complete for all images. ---

# %%
preprocess_mri_pipeline("../nnUNet_raw/Dataset004_ASL/imagesTr/", 
                        "../nnUNet_raw/Dataset004_ASL/imagesPr/",
                        "../nnUNet_raw/Dataset004_ASL/imagesTr/ASL_000_0000.nrrd")
# Out:
# Loading reference image from: ../nnUNet_raw/Dataset004_ASL/imagesTr/ASL_000_0000.nrrd
#
# Processing: ASL_055_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_055_0000.nrrd
#
# Processing: ASL_041_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_041_0000.nrrd
#
# Processing: ASL_060_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_060_0000.nrrd
#
# Processing: ASL_022_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_022_0000.nrrd
#
# Processing: ASL_058_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_058_0000.nrrd
#
# Processing: ASL_036_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_036_0000.nrrd
#
# Processing: ASL_017_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_017_0000.nrrd
#
# Processing: ASL_003_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_003_0000.nrrd
#
# Processing: ASL_066_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_066_0000.nrrd
#
# Processing: ASL_008_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_008_0000.nrrd
#
# Processing: ASL_053_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_053_0000.nrrd
#
# Processing: ASL_029_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_029_0000.nrrd
#
# Processing: ASL_047_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_047_0000.nrrd
#
# Processing: ASL_011_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_011_0000.nrrd
#
# Processing: ASL_005_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_005_0000.nrrd
#
# Processing: ASL_024_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_024_0000.nrrd
#
# Processing: ASL_030_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_030_0000.nrrd
#
# Processing: ASL_040_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_040_0000.nrrd
#
# Processing: ASL_054_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_054_0000.nrrd
#
# Processing: ASL_061_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_061_0000.nrrd
#
# Processing: ASL_037_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_037_0000.nrrd
#
# Processing: ASL_023_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_023_0000.nrrd
#
# Processing: ASL_059_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_059_0000.nrrd
#
# Processing: ASL_002_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_002_0000.nrrd
#
# Processing: ASL_016_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_016_0000.nrrd
#
# Processing: ASL_009_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_009_0000.nrrd
#
# Processing: ASL_067_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_067_0000.nrrd
#
# Processing: ASL_046_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_046_0000.nrrd
#
# Processing: ASL_052_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_052_0000.nrrd
#
# Processing: ASL_028_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_028_0000.nrrd
#
# Processing: ASL_004_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_004_0000.nrrd
#
# Processing: ASL_010_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_010_0000.nrrd
#
# Processing: ASL_031_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_031_0000.nrrd
#
# Processing: ASL_025_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_025_0000.nrrd
#
# Processing: ASL_062_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_062_0000.nrrd
#
# Processing: ASL_018_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_018_0000.nrrd
#
# Processing: ASL_057_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_057_0000.nrrd
#
# Processing: ASL_043_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_043_0000.nrrd
#
# Processing: ASL_039_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_039_0000.nrrd
#
# Processing: ASL_015_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_015_0000.nrrd
#
# Processing: ASL_001_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_001_0000.nrrd
#
# Processing: ASL_020_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_020_0000.nrrd
#
# Processing: ASL_034_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_034_0000.nrrd
#
# Processing: ASL_051_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_051_0000.nrrd
#
# Processing: ASL_045_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_045_0000.nrrd
#
# Processing: ASL_064_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_064_0000.nrrd
#
# Processing: ASL_070_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_070_0000.nrrd
#
# Processing: ASL_026_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_026_0000.nrrd
#
# Processing: ASL_032_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_032_0000.nrrd
#
# Processing: ASL_048_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_048_0000.nrrd
#
# Processing: ASL_013_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_013_0000.nrrd
#
# Processing: ASL_069_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_069_0000.nrrd
#
# Processing: ASL_007_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_007_0000.nrrd
#
# Processing: ASL_063_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_063_0000.nrrd
#
# Processing: ASL_019_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_019_0000.nrrd
#
# Processing: ASL_042_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_042_0000.nrrd
#
# Processing: ASL_038_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_038_0000.nrrd
#
# Processing: ASL_056_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_056_0000.nrrd
#
# Processing: ASL_000_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_000_0000.nrrd
#
# Processing: ASL_014_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_014_0000.nrrd
#
# Processing: ASL_035_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_035_0000.nrrd
#
# Processing: ASL_021_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_021_0000.nrrd
#
# Processing: ASL_044_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_044_0000.nrrd
#
# Processing: ASL_050_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_050_0000.nrrd
#
# Processing: ASL_071_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_071_0000.nrrd
#
# Processing: ASL_065_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_065_0000.nrrd
#
# Processing: ASL_033_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_033_0000.nrrd
#
# Processing: ASL_049_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_049_0000.nrrd
#
# Processing: ASL_027_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_027_0000.nrrd
#
# Processing: ASL_006_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_006_0000.nrrd
#
# Processing: ASL_012_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_012_0000.nrrd
#
# Processing: ASL_068_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset004_ASL/imagesPr/ASL_068_0000.nrrd
#
# --- Preprocessing complete for all images. ---

# %%
preprocess_mri_pipeline("../nnUNet_raw/Dataset005_DWI/imagesTr/", 
                        "../nnUNet_raw/Dataset005_DWI/imagesPr/",
                        "../nnUNet_raw/Dataset005_DWI/imagesTr/DWI_000_0000.nrrd")
# Out:
# Loading reference image from: ../nnUNet_raw/Dataset005_DWI/imagesTr/DWI_000_0000.nrrd
#
# Processing: DWI_016_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_016_0000.nrrd
#
# Processing: DWI_002_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_002_0000.nrrd
#
# Processing: DWI_023_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_023_0000.nrrd
#
# Processing: DWI_028_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_028_0000.nrrd
#
# Processing: DWI_009_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_009_0000.nrrd
#
# Processing: DWI_025_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_025_0000.nrrd
#
# Processing: DWI_010_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_010_0000.nrrd
#
# Processing: DWI_004_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_004_0000.nrrd
#
# Processing: DWI_003_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_003_0000.nrrd
#
# Processing: DWI_017_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_017_0000.nrrd
#
# Processing: DWI_022_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_022_0000.nrrd
#
# Processing: DWI_008_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_008_0000.nrrd
#
# Processing: DWI_024_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_024_0000.nrrd
#
# Processing: DWI_005_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_005_0000.nrrd
#
# Processing: DWI_011_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_011_0000.nrrd
#
# Processing: DWI_019_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_019_0000.nrrd
#
# Processing: DWI_021_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_021_0000.nrrd
#
# Processing: DWI_014_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_014_0000.nrrd
#
# Processing: DWI_000_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_000_0000.nrrd
#
# Processing: DWI_012_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_012_0000.nrrd
#
# Processing: DWI_006_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_006_0000.nrrd
#
# Processing: DWI_027_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_027_0000.nrrd
#
# Processing: DWI_018_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_018_0000.nrrd
#
# Processing: DWI_020_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_020_0000.nrrd
#
# Processing: DWI_001_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_001_0000.nrrd
#
# Processing: DWI_015_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_015_0000.nrrd
#
# Processing: DWI_007_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_007_0000.nrrd
#
# Processing: DWI_013_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_013_0000.nrrd
#
# Processing: DWI_026_0000.nrrd
# Applying N4 bias field correction...
# Applying histogram matching...
# Rescaling intensities to [0, 1]...
# Saving processed image to: ../nnUNet_raw/Dataset005_DWI/imagesPr/DWI_026_0000.nrrd
#
# --- Preprocessing complete for all images. ---
